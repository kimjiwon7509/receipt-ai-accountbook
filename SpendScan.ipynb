# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjiwon7509/receipt-ai-accountbook/blob/main/SpendScan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
